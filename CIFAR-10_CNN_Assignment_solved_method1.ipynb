# %% [markdown]
# SOLVING DATASET USING DATA BASIC CNN MODEL

# %% [markdown]
# IMPORT NECESSARY LIBRARIES:-

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
print('Importing successfully done')
# Out:
# Importing successfully done

# %% [markdown]
# LOAD CIFAR-10 DATASET:-

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Summarize the dataset:

# The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. 
# The dataset is divided into 50,000 training images and 10,000 testing images. 
# The classes are 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck' respectively.

# %% [markdown]
# PRE-PROCESSING THE DATASET:-

# %%
x_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
x_test
# Out:
# array([[[[158, 112,  49],
#          [159, 111,  47],
#          [165, 116,  51],
#          ...,
#          [137,  95,  36],
#          [126,  91,  36],
#          [116,  85,  33]],
#
#         [[152, 112,  51],
#          [151, 110,  40],
#          [159, 114,  45],
#          ...,
#          [136,  95,  31],
#          [125,  91,  32],
#          [119,  88,  34]],
#
#         [[151, 110,  47],
#          [151, 109,  33],
#          [158, 111,  36],
#          ...,
#          [139,  98,  34],
#          [130,  95,  34],
#          [120,  89,  33]],
#
#         ...,
#
#         [[ 68, 124, 177],
#          [ 42, 100, 148],
#          [ 31,  88, 137],
#          ...,
#          [ 38,  97, 146],
#          [ 13,  64, 108],
#          [ 40,  85, 127]],
#
#         [[ 61, 116, 168],
#          [ 49, 102, 148],
#          [ 35,  85, 132],
#          ...,
#          [ 26,  82, 130],
#          [ 29,  82, 126],
#          [ 20,  64, 107]],
#
#         [[ 54, 107, 160],
#          [ 56, 105, 149],
#          [ 45,  89, 132],
#          ...,
#          [ 24,  77, 124],
#          [ 34,  84, 129],
#          [ 21,  67, 110]]],
#
#
#        [[[235, 235, 235],
#          [231, 231, 231],
#          [232, 232, 232],
#          ...,
#          [233, 233, 233],
#          [233, 233, 233],
#          [232, 232, 232]],
#
#         [[238, 238, 238],
#          [235, 235, 235],
#          [235, 235, 235],
#          ...,
#          [236, 236, 236],
#          [236, 236, 236],
#          [235, 235, 235]],
#
#         [[237, 237, 237],
#          [234, 234, 234],
#          [234, 234, 234],
#          ...,
#          [235, 235, 235],
#          [235, 235, 235],
#          [234, 234, 234]],
#
#         ...,
#
#         [[ 87,  99,  89],
#          [ 43,  51,  37],
#          [ 19,  23,  11],
#          ...,
#          [169, 184, 179],
#          [182, 197, 193],
#          [188, 202, 201]],
#
#         [[ 82,  96,  82],
#          [ 46,  57,  36],
#          [ 36,  44,  22],
#          ...,
#          [174, 189, 183],
#          [185, 200, 196],
#          [187, 202, 200]],
#
#         [[ 85, 101,  83],
#          [ 62,  75,  48],
#          [ 58,  67,  38],
#          ...,
#          [168, 183, 178],
#          [180, 195, 191],
#          [186, 200, 199]]],
#
#
#        [[[158, 190, 222],
#          [158, 187, 218],
#          [139, 166, 194],
#          ...,
#          [228, 231, 234],
#          [237, 239, 243],
#          [238, 241, 246]],
#
#         [[170, 200, 229],
#          [172, 199, 226],
#          [151, 176, 201],
#          ...,
#          [232, 232, 236],
#          [246, 246, 250],
#          [246, 247, 251]],
#
#         [[174, 201, 225],
#          [176, 200, 222],
#          [157, 179, 199],
#          ...,
#          [230, 229, 232],
#          [250, 249, 251],
#          [245, 244, 247]],
#
#         ...,
#
#         [[ 31,  40,  45],
#          [ 30,  39,  44],
#          [ 26,  35,  40],
#          ...,
#          [ 37,  40,  46],
#          [  9,  13,  14],
#          [  4,   7,   5]],
#
#         [[ 23,  34,  39],
#          [ 27,  38,  43],
#          [ 25,  36,  41],
#          ...,
#          [ 19,  20,  24],
#          [  4,   6,   3],
#          [  5,   7,   3]],
#
#         [[ 28,  41,  47],
#          [ 30,  43,  50],
#          [ 32,  45,  52],
#          ...,
#          [  5,   6,   8],
#          [  4,   5,   3],
#          [  7,   8,   7]]],
#
#
#        ...,
#
#
#        [[[ 20,  15,  12],
#          [ 19,  14,  11],
#          [ 15,  14,  11],
#          ...,
#          [ 10,   9,   7],
#          [ 12,  11,   9],
#          [ 13,  12,  10]],
#
#         [[ 21,  16,  13],
#          [ 20,  16,  13],
#          [ 18,  17,  12],
#          ...,
#          [ 10,   9,   7],
#          [ 10,   9,   7],
#          [ 12,  11,   9]],
#
#         [[ 21,  16,  13],
#          [ 21,  17,  12],
#          [ 20,  18,  11],
#          ...,
#          [ 12,  11,   9],
#          [ 12,  11,   9],
#          [ 13,  12,  10]],
#
#         ...,
#
#         [[ 33,  25,  13],
#          [ 34,  26,  15],
#          [ 34,  26,  15],
#          ...,
#          [ 28,  25,  52],
#          [ 29,  25,  58],
#          [ 23,  20,  42]],
#
#         [[ 33,  25,  14],
#          [ 34,  26,  15],
#          [ 34,  26,  15],
#          ...,
#          [ 27,  24,  52],
#          [ 27,  24,  56],
#          [ 25,  22,  47]],
#
#         [[ 31,  23,  12],
#          [ 32,  24,  13],
#          [ 33,  25,  14],
#          ...,
#          [ 24,  23,  50],
#          [ 26,  23,  53],
#          [ 25,  20,  47]]],
#
#
#        [[[ 25,  40,  12],
#          [ 15,  36,   3],
#          [ 23,  41,  18],
#          ...,
#          [ 61,  82,  78],
#          [ 92, 113, 112],
#          [ 75,  89,  92]],
#
#         [[ 12,  25,   6],
#          [ 20,  37,   7],
#          [ 24,  36,  15],
#          ...,
#          [115, 134, 138],
#          [149, 168, 177],
#          [104, 117, 131]],
#
#         [[ 12,  25,  11],
#          [ 15,  29,   6],
#          [ 34,  40,  24],
#          ...,
#          [154, 172, 182],
#          [157, 175, 192],
#          [116, 129, 151]],
#
#         ...,
#
#         [[100, 129,  81],
#          [103, 132,  84],
#          [104, 134,  86],
#          ...,
#          [ 97, 128,  84],
#          [ 98, 126,  84],
#          [ 91, 121,  79]],
#
#         [[103, 132,  83],
#          [104, 131,  83],
#          [107, 135,  87],
#          ...,
#          [101, 132,  87],
#          [ 99, 127,  84],
#          [ 92, 121,  79]],
#
#         [[ 95, 126,  78],
#          [ 95, 123,  76],
#          [101, 128,  81],
#          ...,
#          [ 93, 124,  80],
#          [ 95, 123,  81],
#          [ 92, 120,  80]]],
#
#
#        [[[ 73,  78,  75],
#          [ 98, 103, 113],
#          [ 99, 106, 114],
#          ...,
#          [135, 150, 152],
#          [135, 149, 154],
#          [203, 215, 223]],
#
#         [[ 69,  73,  70],
#          [ 84,  89,  97],
#          [ 68,  75,  81],
#          ...,
#          [ 85,  95,  89],
#          [ 71,  82,  80],
#          [120, 133, 135]],
#
#         [[ 69,  73,  70],
#          [ 90,  95, 100],
#          [ 62,  71,  74],
#          ...,
#          [ 74,  81,  70],
#          [ 53,  62,  54],
#          [ 62,  74,  69]],
#
#         ...,
#
#         [[123, 128,  96],
#          [132, 132, 102],
#          [129, 128, 100],
#          ...,
#          [108, 107,  88],
#          [ 62,  60,  55],
#          [ 27,  27,  28]],
#
#         [[115, 121,  91],
#          [123, 124,  95],
#          [129, 126,  99],
#          ...,
#          [115, 116,  94],
#          [ 66,  65,  59],
#          [ 27,  27,  27]],
#
#         [[116, 120,  90],
#          [121, 122,  94],
#          [129, 128, 101],
#          ...,
#          [116, 115,  94],
#          [ 68,  65,  58],
#          [ 27,  26,  26]]]], dtype=uint8)

# %%
y_test
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %% [markdown]
# DISPLAY IMAGES TO VERIFY THE DATA:-

# %%
# Define class labels
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Function to display a grid of images with their labels
def display_images(images, labels, class_names, num_images=25):
    plt.figure(figsize=(10, 10))
    for i in range(num_images):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i])
        plt.xlabel(class_names[labels[i][0]])
    plt.show()

# Display first 25 images from the training set
display_images(x_train, y_train, class_names)

# %% [markdown]
# FEATURE SCALING OF THE DATA :-

# %%
# Normalize the images to a range of 0 to 1

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# We import additional libraries

from tensorflow.keras.utils import to_categorical
print('Importing successfully done')
# Out:
# Importing successfully done

# %%
# One-hot encode the labels

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 10), (10000, 10))

# %% [markdown]
# LOAD THE MODEL:-

# %%
# We import additional libraries

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
print('Importing successfully done')
# Out:
# Importing successfully done

# %% [markdown]
# CREATING SEQUENTIAL MODEL (CNN):-

# %%
# Build the model

model = Sequential()
model
# Out:
# <Sequential name=sequential, built=False>

# %% [markdown]
# ASSIGNING CONVOLUTIONAL LAYERS AND MAXPOOLING TO THE DATA:-

# %%
# Convolutional Layer 1

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))

# Convolutional Layer 2

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Convolutional Layer 3

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
# Out:
# C:\Users\torne\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %% [markdown]
# ADDING DENSE LAYERS:-

# %%
# Flatten the results to feed into a dense layer

model.add(Flatten())

# %%
# Fully connected layer

model.add(Dense(64, activation='relu'))

# %%
# Output layer

model.add(Dense(10, activation='softmax'))

# %%
# Compile the model

model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 4, 4, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 2, 2, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 73,418 (286.79 KB)
#  Trainable params: 73,418 (286.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# TRAIN THE MODEL(CNN):-

# %%
#Train the model

history = model.fit(x_train, y_train,batch_size=32, epochs=50, validation_data=(x_test, y_test))

# An epoch means training the neural network with all the training data for one cycle. Here I have used 50 epochs:
# Out:
# Epoch 1/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 46s 28ms/step - accuracy: 0.6307 - loss: 1.0501 - val_accuracy: 0.6457 - val_loss: 1.0157
# Epoch 2/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 28ms/step - accuracy: 0.6669 - loss: 0.9576 - val_accuracy: 0.6474 - val_loss: 1.0155
# Epoch 3/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.6825 - loss: 0.8962 - val_accuracy: 0.6679 - val_loss: 0.9704
# Epoch 4/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 86s 30ms/step - accuracy: 0.7041 - loss: 0.8466 - val_accuracy: 0.6776 - val_loss: 0.9388
# Epoch 5/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 27ms/step - accuracy: 0.7239 - loss: 0.7908 - val_accuracy: 0.6800 - val_loss: 0.9338
# Epoch 6/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.7397 - loss: 0.7485 - val_accuracy: 0.6837 - val_loss: 0.9402
# Epoch 7/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 27ms/step - accuracy: 0.7529 - loss: 0.7135 - val_accuracy: 0.7056 - val_loss: 0.8712
# Epoch 8/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.7615 - loss: 0.6756 - val_accuracy: 0.6865 - val_loss: 0.9483
# Epoch 9/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 74s 23ms/step - accuracy: 0.7681 - loss: 0.6596 - val_accuracy: 0.7089 - val_loss: 0.8767
# Epoch 10/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 37s 23ms/step - accuracy: 0.7781 - loss: 0.6277 - val_accuracy: 0.7021 - val_loss: 0.8997
# Epoch 11/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.7878 - loss: 0.6030 - val_accuracy: 0.7056 - val_loss: 0.8786
# Epoch 12/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.7968 - loss: 0.5820 - val_accuracy: 0.6962 - val_loss: 0.9398
# Epoch 13/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.8011 - loss: 0.5625 - val_accuracy: 0.6865 - val_loss: 0.9550
# Epoch 14/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.8083 - loss: 0.5416 - val_accuracy: 0.7112 - val_loss: 0.8960
# Epoch 15/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 25ms/step - accuracy: 0.8150 - loss: 0.5255 - val_accuracy: 0.6924 - val_loss: 0.9640
# Epoch 16/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.8140 - loss: 0.5199 - val_accuracy: 0.6956 - val_loss: 0.9856
# Epoch 17/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 28ms/step - accuracy: 0.8292 - loss: 0.4853 - val_accuracy: 0.7110 - val_loss: 0.9337
# Epoch 18/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8331 - loss: 0.4741 - val_accuracy: 0.7041 - val_loss: 0.9834
# Epoch 19/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 44s 28ms/step - accuracy: 0.8381 - loss: 0.4610 - val_accuracy: 0.6932 - val_loss: 1.0292
# Epoch 20/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.8422 - loss: 0.4426 - val_accuracy: 0.7004 - val_loss: 1.0128
# Epoch 21/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 86s 31ms/step - accuracy: 0.8467 - loss: 0.4297 - val_accuracy: 0.6984 - val_loss: 1.0412
# Epoch 22/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 79s 29ms/step - accuracy: 0.8536 - loss: 0.4135 - val_accuracy: 0.6972 - val_loss: 1.0378
# Epoch 23/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 30ms/step - accuracy: 0.8565 - loss: 0.3997 - val_accuracy: 0.6916 - val_loss: 1.0984
# Epoch 24/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 29ms/step - accuracy: 0.8580 - loss: 0.3951 - val_accuracy: 0.7067 - val_loss: 1.0624
# Epoch 25/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 48s 31ms/step - accuracy: 0.8637 - loss: 0.3796 - val_accuracy: 0.6928 - val_loss: 1.1229
# Epoch 26/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 48s 31ms/step - accuracy: 0.8676 - loss: 0.3673 - val_accuracy: 0.7024 - val_loss: 1.0940
# Epoch 27/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 48s 31ms/step - accuracy: 0.8730 - loss: 0.3507 - val_accuracy: 0.6971 - val_loss: 1.1342
# Epoch 28/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.8738 - loss: 0.3440 - val_accuracy: 0.6955 - val_loss: 1.1884
# Epoch 29/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 72s 29ms/step - accuracy: 0.8739 - loss: 0.3479 - val_accuracy: 0.6952 - val_loss: 1.1892
# Epoch 30/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.8817 - loss: 0.3288 - val_accuracy: 0.6962 - val_loss: 1.1738
# Epoch 31/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 30ms/step - accuracy: 0.8841 - loss: 0.3204 - val_accuracy: 0.6935 - val_loss: 1.2511
# Epoch 32/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 47s 30ms/step - accuracy: 0.8884 - loss: 0.3118 - val_accuracy: 0.6935 - val_loss: 1.2467
# Epoch 33/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 79s 28ms/step - accuracy: 0.8903 - loss: 0.3056 - val_accuracy: 0.6937 - val_loss: 1.3179
# Epoch 34/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 44s 28ms/step - accuracy: 0.8952 - loss: 0.2924 - val_accuracy: 0.6921 - val_loss: 1.3016
# Epoch 35/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 28ms/step - accuracy: 0.8941 - loss: 0.2918 - val_accuracy: 0.6911 - val_loss: 1.3171
# Epoch 36/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 27ms/step - accuracy: 0.8950 - loss: 0.2847 - val_accuracy: 0.6849 - val_loss: 1.3859
# Epoch 37/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.9009 - loss: 0.2738 - val_accuracy: 0.6935 - val_loss: 1.3728
# Epoch 38/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.9035 - loss: 0.2664 - val_accuracy: 0.6969 - val_loss: 1.3456
# Epoch 39/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 47s 30ms/step - accuracy: 0.9081 - loss: 0.2543 - val_accuracy: 0.6838 - val_loss: 1.4382
# Epoch 40/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.9063 - loss: 0.2596 - val_accuracy: 0.6885 - val_loss: 1.4048
# Epoch 41/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 46s 29ms/step - accuracy: 0.9105 - loss: 0.2461 - val_accuracy: 0.6878 - val_loss: 1.4719
# Epoch 42/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 84s 30ms/step - accuracy: 0.9070 - loss: 0.2488 - val_accuracy: 0.6918 - val_loss: 1.4519
# Epoch 43/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 46s 29ms/step - accuracy: 0.9105 - loss: 0.2409 - val_accuracy: 0.6893 - val_loss: 1.5095
# Epoch 44/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 35ms/step - accuracy: 0.9142 - loss: 0.2317 - val_accuracy: 0.6881 - val_loss: 1.4928
# Epoch 45/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 34ms/step - accuracy: 0.9139 - loss: 0.2328 - val_accuracy: 0.6878 - val_loss: 1.5596
# Epoch 46/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 50s 32ms/step - accuracy: 0.9158 - loss: 0.2261 - val_accuracy: 0.6865 - val_loss: 1.6184
# Epoch 47/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 47s 30ms/step - accuracy: 0.9182 - loss: 0.2241 - val_accuracy: 0.6829 - val_loss: 1.6192
# Epoch 48/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 47s 30ms/step - accuracy: 0.9206 - loss: 0.2150 - val_accuracy: 0.6879 - val_loss: 1.6657
# Epoch 49/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 46s 29ms/step - accuracy: 0.9247 - loss: 0.2058 - val_accuracy: 0.6806 - val_loss: 1.7258
# Epoch 50/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 28ms/step - accuracy: 0.9200 - loss: 0.2172 - val_accuracy: 0.6869 - val_loss: 1.6884

# %%
# Define needed variables
tr_loss = history.history['loss']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]

Epochs = [i+1 for i in range(len(tr_loss))]
loss_label = f'best epoch= {str(index_loss + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout
plt.show()

# %%
# Accuracy score:

val_accuracy = np.max(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 71.12%

# %%
# Now testing new Model prediction by providing Test Data set

y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step
# array([[False, False, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        [False, False, False, ..., False, False,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False,  True, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False]])

# %% [markdown]
# EVALUATE THE MODEL (CNN):-

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6926 - loss: 1.6083
# Test accuracy: 0.6869000196456909

# %% [markdown]
# PLOT TRAINING HISTORY:-

# %%
# Visualize training history

plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Conclusion:

# We can see that the val_accuracy: 71.12%.
# The CNN model for this dataset gives us a Test accuracy: 68.69%.
# In order to obtain the above result, the best epoch was 7th cycle which gave us the best result.
